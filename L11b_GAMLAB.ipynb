# %% [markdown]
# In The Name of God

# %% [markdown]
# # L11 Matplotlib
# - Matplotlib introduction
#
# This is start of our lecture

# %%
a=10
print(a)
print('salam')
# Out:
# 10
# salam

# %% [markdown]
# # Matplotlib Introduction
# Matplotib baraye rasm hastr
#
# varede PIP shavid va anra install konid
# badesh varede cmd.exe shavid pip install matplotlib ra benevisid
# - pip install matplotlib
#
# badesh varespyder shavid va anra import konid

# %%
import matplotlib.pyplot as plt
# plt mokhafafe ma hast

# %% [markdown]
# Sade tarin in hast k yek x va yek y dashte bashim va bekhaym k anra rasm konim

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

plt.plot(x,y)
plt.show()

# %%
import numpy as np
a=np.array([1,2,3,4,5])
b=np.array([10,20,30,40,50])

plt.plot(a,b)
plt.show()

# %% [markdown]
# # Just point

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
#bjeaye inke benvisam plt.plot(x,y) , ye 'o' ezafe mikonam
plt.plot(x,y,'o')
plt.show()

# %%
plt.plot(x,y,'*')
plt.show()

# %%
plt.plot(x,y,'x')
plt.show()

# %%
plt.plot(x,y,'H')
plt.show()

# %% [markdown]
# # Point + Line

# %%
plt.plot(x,y,marker='o')
plt.show()

# %%
plt.plot(x,y,marker='*')
plt.show()

# %%
#Marker sizeto avaz koni ms
plt.plot(x,y,marker='*' , ms=30)

# %%
plt.plot(x,y,marker='*' , ms=3)

# %%
plt.plot(x,y,marker='*' ,ms=30, mec='r')

# %%
plt.plot(x,y,marker='*' ,ms=30, mec='r' , mfc='g')

# %% [markdown]
# Point khali --> plt.plot(x,y,'o')
# Point + Line --> plt.plot(x,y,marker='o') --> ms --> size point, mec --> range doresh , mfc-->range dakhelesh
#
# # Jayer marker-->
#
# - 'o'	Circle
# - '*'	Star
# - '.'	Point
# - ','	Pixel
# - 'x'	X
# - 'X'	X (filled)
# - '+'	Plus
# - 'P'	Plus (filled)
# - 's'	Square
# - 'D'	Diamond
# - 'd'	Diamond (thin)
# - 'p'	Pentagon
# - 'H'	Hexagon
# - 'h'	Hexagon
# - 'v'	Triangle Down
# - '^'	Triangle Up
# - '<'	Triangle Left
# - '>'	Triangle Right
# - '1'	Tri Down
# - '2'	Tri Up
# - '3'	Tri Left
# - '4'	Tri Right
# - '|'	Vline
# - '_'	Hline
#
#
#
#
#
# # -----colours------
# - 'r' - Red
# - 'g' - Green
# - 'b' - Blue
# - 'c' - Cyan
# - 'm' - Magenta
# - 'y' - Yellow
# - 'k' - Black
# - 'w' - White

# %% [markdown]
# # Just line

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,ls='-')
plt.show()

# %%
plt.plot(x,y,ls='--')
plt.show()

# %%
plt.plot(x,y,ls='-.')
plt.show()

# %%
plt.plot(x,y,ls=':')
plt.show()

# %%
plt.plot(x,y,ls=':',color='r')
plt.show()

# %%
plt.plot(x,y,ls=':',c='r')
plt.show()

# %%
plt.plot(x,y,ls=':',linewidth=20)
plt.show()

# %%
plt.plot(x,y,linewidth=20)
plt.show()

# %% [markdown]
# # Overview
#
# import matplotlib.plyplot as plt ---> for visulaization
#
#
# -------> plt.plot() ---> rasme x , y
#
#
# x ,y --> list, tuple, set , np.array
#
#
# plt.show() ---> akhare har khat baya dbnvisi
#
#
#
# plt.plot(x,y) ---> Line midan
#
# plt.plot(x,y,...... arguments)
#
#
# arguments---> taghire khat has
#
# ls -->line style
# '-' --> default
# '--'
# '-.'
# ':'
#
#
# c , colour:
# 'r' 'g'
#
#
# plt.plot(x,y,'o') --> Point
#
#
#
#
# plt.plot(x,y,marker='o') --- Point + Line
# o , * H  X ,....
#
# ms= size point
# mec--> rnage atrafe
# mfc---> range dakhel

# %%
#mesale ghashang ham barat bezanm
import numpy as np
x=np.linspace(0,np.pi , 100)
y=np.sin(x)


plt.plot(x,y,ls=':',c='r')
plt.show()

# %% [markdown]
# - Plot ----> yek khat ro rasm konid
# - scatter ---> noghate data ro rasm koni
# - pie chart --> darsadi
# - bar chart --> amari
# - Histogram --> tozi haye amri ro rasm mikonid
#
# - 3D rasam konid
# - animation
#
#
#
# plt.plot()
# plt.scatter()
# plt.pie()
# plt.bar()
# plt.hist()
# plt.barh()
#
#
#
#
#
# tahesh ---> plt.show() --> hatmana bokhore
# # plt.show() niaz hast

# %% [markdown]
# in nokat baraye hameye tasavir, plot, scatter, bar, hist ,............

# %%
import matplotlib.pyplot as plt

x=np.array([1,2,3,4,5])
y=np.array([10,20,30,40,50])

plt.plot(x,y)
plt.show()

# %% [markdown]
# Biroone tasvir agar taghiri mikhahid bedahid
# bayad ghable plt.show() emal konid
#
#
# # ----------------------
# plt.plot() , plt.scatter() ,......
#
#
# # ----------------------
# plt.title()
# plt.xlabel()
# plt.ylabel()
# plt.legend()
#
#
# # ----------------------
# ghabl az
# plt.show()

# %%
plt.plot(x,y)


plt.title(' Nemoodare aslie man' )

plt.show()

# %%
plt.plot(x,y)


plt.title(' Nemoodare aslie man' )
plt.xlabel('tedade afrad')
plt.ylabel('meyare quality')
plt.show()

# %%
plt.plot(x,y)


plt.title(' Nemoodare aslie man' )
plt.xlabel('tedade afrad')
plt.ylabel('meyare quality')
plt.xlim(0,10)
plt.ylim(0,200)
plt.show()

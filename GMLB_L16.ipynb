# %% [markdown]
# # In The Name of GOD
#
# # L16 : AI + ML

# %% [markdown]
# AI = Artificial intelligence
#
# Human ---> data ro bebinid --> ya mitone az cheshm ha bashe ya az goosh ( + cheshae ,...)
# Dar maghze ( brain , Intelligent) ---> az data ha ma yad migirim
# amal ---> bar asase yadgirimon kar haro anjam midim
#
#
#
# Intelligence----> 3 step
# 1---> data ro daryaft kone ( AX , manzare , seda , video , ketab , tasavir  , adad ,....)
# 2---> az data yad begire
# 3---> betoone bar asase yadgirish (manteghi k bedast ovorde)--> amal kone / pishbini kone, dasdte bandi kone, ....
#
# - AI
# - AI 1st generation
# - AI 2nd generation
#
#
# # AI 1St generation
#
# eneghebale snaati --> machine ha (ccomputer , azmayehsgah , karkhone ) --> hameye ina ba bargh kar mikrdn
# ---> ba computer kar kone --> automation --> khodkaer shenakhte mishe
#
# ghadimn --> yechizio beboran , dastgahe ghavi bood , yek ensan poshtesh vay msiad ye zoore kami mzid, oon dastgah be gone e bod ke in ghodrtato 100 abrabar -> borehs ro najam midad --> ensan too kar bod -> hameye ghatat yeksan nabodan , sorat kam bod , khata dasht , khastegi --> mass production
#
#
# --> aUTOMATION Bia inajm bdim --> robots , autom,ated inkara konim
#
# CNC ---> automation anjam midim --> AI
#
# if else , for ...
#
# be yek macchine dastor bdi --> ba yek code  x, y va bere for anjam bede
# ino hoshmand midonesan
#
#
# CNC ,
#
#
# ROBOT -->
# SENSOR DARAN --> MECHANIC --> ELECTRICI -0-PAULS
#
#
# ROOYE DOTA BAZOHASH DOTA SENSORE
#
# AG SENSORE RAST KHORD ZZAMIN
#
# SENSOR768
#
#
#
#
# if sensor768==True:
#
# else
#
# robot nasle 1

# %% [markdown]
# - Telgeram bot

# %%
import telegram 
#too khode tleegrma yek bot msiazi -> Token --> 23019djh9-sd7nqy932yuq734ydr87qy3n98syq87d3mhs
#az laptabehs --> oon robot ro control kone
telegram.token('23019djh9-sd7nqy932yuq734ydr87qy3n98syq87d3mhs')

telegram.activate() #--


def start(commands, update):

    telegram.send_message('salam be bote ma khoshg oomadid')

products={
'k10' : 1000
'k23' : 2000

'k28' : 4000



}


#products['k28'] ---> 2000


def message_handler(messages):
    user_message=telegram.message.context()

#slm Salam  salam

    
    if 'salam' in user_message.strip().lower() or 'slm' in user_message.strip().lower() :
        telegram.send_message('salam arz shod janam?')

    if 'khoobi' in user_message.strip().lower():
        telegram.send_message('mamnoon shomaham khoobi?')

    if 'price' in user_message.strip().lower():
        for keys in products.keys():
            if keys in user_message.strip().lower():
                telegeram.send_message(f'gheymate mahsoole morede nazar hast : {products[keys]}')
        

    
#10 % moshtari haro rah bendazim

#Rule-based raftim jolo
#if else ......

#intelligent bekar bebaam

#Mitonesan ba ensan shoro konan harf bzn

#ba if , else , if else

#----> Nasle 1 hooshe masnooe

#send.message('mivast?;)

#if response=='yes:
#        soaled dg
#else:
#
# Out:
#   Cell In[2], line 14
#     'k10' : 1000
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# - AI 1st generation
#
# if , else
# hooshmand nabode
# rule-based boode
# kheylie kheylii zaman bare
# Emkane yadgiri nadare
# pishrafti nadarer --> dobare bayad biay rule behesh ezafe koni ,khdoesh nmitone behtar beshe
#
#
# AI 1st geenration just joke
#
# automated Programm

# %%
'''
2nd generation of AI -----------------

100% --> 10% rule based / 10% hoosh haye far e / 70,80 % AI -----> MACHINE LEARNING

YADGIRIE MASHIN ---> in method ha hastan k baes mishe be yechizi mesle machien begim AI



Model haye amari darim --> k mitone rabeteye beyne vorodi va khoroji ro yad begire



Kole jahano ma bayad b voroodi va khoroji tabdil konim 


harchi dar jahan mishe be vorodi av khorji tabdil beshe

General -->

email maid be gmaile shoam ---> 

vorodi --> email hast ( email haye mamoli bashe , spam , tablighat, ..)

----->
khrooji --> aya spame ya spam nist




tarikhe roozha --> shoam mgii agha farda gheymate dollar chande? hafteye dg chande?

vorodi --> rooz
khoroji --> gehytmate dorllar





AI ----> BOX   BLACK BOX []



Input ------> [] -----> OUTPUT

CHATGPT , AI-BASED GENERATOR, AI CHATBOT -->
VORODI (PROMPT USER) -----> [] ------> Response (ai-genrated)
TESLA

Tasaviran (vorodi) -----> [] -----> Named entity ( bedone har tike chie, ensane aber, machine ,..)






step0-----------------------------
Ghabl az inke az Ml , AI estefade konim kafie k masalato bebini va tabdil koni b ye vorodi va khoroji



Machine learning --> branch az AI 

---> statistcial methods --> model haye ziadi darim


               -------------ai--------------
1-MACHINE LEARNING(70,80%)        2-Optimization 3-rule-basewd 4,........


-----------ML Category---------------------
supervised learning
unsupervised learning
RL --> reiforcnement learning
Deep learning



dar har 4 ta ---->


[Machine learningmodel] ---> BOX

Input ----> BOX ----> Output


Machine elarning mdoel (amarie ma hastan-)----> rabeteye beyne output va input ro dar miaran



data (bayad data dahste bashi) --> mobtani bar dade 
dade ---> format (vorooodi ) | (khoroji)

ML MODELS-----> RABETEYE BEYNE VORODI VA KHOROJI ---> bar asare yekseri ravabat va modelsazi haye amari bedast miaran
midonan ch rabete ee beyenr khoroji va vorodie bar asase dadeh

pas mitoni to behesh dg vorodie jadid bdi , ---> khjoroji ro bde
hamoon vorodi ro bdi --> khoroji bde
fast , rely


-------------------------------
dade haro mdisid
yad migrf
bar asare yadgirish --> amal miakrd 



ML --> data (vbroodi/khroji) mibine
yad migire rabteeye beyne vorodi va khorojie ( amari)
bar asare oon rabete, ag vorodi bedi mizare too rabeta --> khorojio bht pas mide


data --------------
email --> barchasb zadi [ spam, /not spam]


ax ha-------------------
axe dg --> sag / gorbe


chat gpt------
koli question , reponse
salam khobi / bale khoobam



------ENGINERRING--------- (MOHANDESI)

ya dari ba ye methodi , dastgahi , ba ye raveshi

Variables ---> moteghayer ha ---> daste khdoete yani shoma miton itaghiresh bdi



process parameters---------------------------
3D PRINTING --------------
setting --> dama , speed , parametr----> default , 

dfault ---> yechizi print -->tahvil mide

process parameters -----> Vorodi ( choon ma mitonim taghiresh bdim)

hadafi --> goal --> estehakm , shafafiat , zebri ,..... ---> azmayeshgah andaze gri mikoni estehkam
tensiel --> oon nemoen ro mikeshe --> andaze giri --> ye adad behet --> young modulus 
adad --> criteria --> shakhese k msianji k khobe mahsolet , karet --> hadafe --> criteria maximize , minimize


quaLITY parameter





toye azmayeshgah --> process parameetrs --> taghir bdi --> ag man taghir bdm 
soorato atghir bdm --> chiz toldi mikonm quality parameter (estehkameshe) aya taghir mikone?




sorato ziad koni --> sari tar chap shdoe ---> 

tahlil --> bekhatere inke sari atr dare chap mishe --> vaght nmikone khob beham bechabse--> estehakmesh kame

ag beri azmayesh , 
rabete ye beyne process parameter + quaLITY PARAMETER MSOHAKAHS NIS
va to be donbaleshi

ag in rabete ro bdoni

try error --> azmayehsgah 20 ta nemone done done sorato ziad , sorato kam , damaro zdamaro kam , ---> estehakamasho


process parameter --------> esthakam

ey kash yechi bood k rabeteye beyten in dota ro midoens


estehkam = 43* process parameters**2 + 19


process parasmeter --> sorato mszasahtam --> estehakmo migofd ey kash bood

machine learning miad jolo ---> mige agha ag bman tedadi data bedi
man rsbete ye beyne in dotaro behet midm 




cchoon ba estefade az algorithem ham mitonam in rabete ro peyda konm
estehkam = 43* process parameters**2 + 19





'''
# Out:
# '\n2nd generation of AI -----------------\n\n100% --> 10% rule based / 10% hoosh haye far e / 70,80 % AI -----> MACHINE LEARNING\n\nYADGIRIE MASHIN ---> in method ha hastan k baes mishe be yechizi mesle machien begim AI\n\n\n\nModel haye amari darim --> k mitone rabeteye beyne vorodi va khoroji ro yad begire\n\n\n\nKole jahano ma bayad b voroodi va khoroji tabdil konim \n\n\nharchi dar jahan mishe be vorodi av khorji tabdil beshe\n\nGeneral -->\n\nemail maid be gmaile shoam ---> \n\nvorodi --> email hast ( email haye mamoli bashe , spam , tablighat, ..)\n\n----->\nkhrooji --> aya spame ya spam nist\n\n\n\n\ntarikhe roozha --> shoam mgii agha farda gheymate dollar chande? hafteye dg chande?\n\nvorodi --> rooz\nkhoroji --> gehytmate dorllar\n\n\n\n\n\nAI ----> BOX   BLACK BOX []\n\n\n\nInput ------> [] -----> OUTPUT\n\nCHATGPT , AI-BASED GENERATOR, AI CHATBOT -->\nVORODI (PROMPT USER) -----> [] ------> Response (ai-genrated)\nTESLA\n\nTasaviran (vorodi) -----> [] -----> Named entity ( 
# ...

# %% [markdown]
# # ML CLASSIFICATION
#
# DATA:
# input ------ BOX ---- OUTPUT
#
#
# - Supervised ML
# - Unsupervsied ML
# - RL
# - DEEP LEARNING
#
#
#
# -
# mesal --> ax
#
# 100 ta ax gorbe o sag daram
# ag jolosh label bznm , axe avali sage , gorbas, gorbas , gorba, label -->
#
# ax          label
# input ----> output
#
# ML --> yadbgire --> Supervised learning --> yadgirie tahte nezarat
#
#
# -
#
# 100 ta ax grobe o sag darma ,label nznm
# input --> az oon mikham khodesh biad khooshe bandi , tafavot ha shabahat ha , --> b 2 daste khodesh taghsim kone 1 , 2
# pattern ro kashf kone --> Unsupervised learning --> yadghiriet etahte gheyre nezarati
#
#
# -
#
# Traditional learning---------> deep learning
#
# Supervised, unsupervised --> data amade mikonim ---> model --> mdoel yad migire
# ag dat alabel dasht --> supervide / ag label --> unsupervised
# dataye shoam dg bish az nahayat kh ziade--> model haye shomaham kh kh pichide tar,laye haye bishatri --> deep learning
#
#
#
# gahan shoma data ro amade nmeikone , balke yek mohiti dari --> mikhay modelet bere tooo mohit
# bsoorate zende data begire
# hey done done data bdi behezsh va yad bgire
# kole data ro yeja behesh nmidim
# balke ghatre ghatre too khdoe mohit
# interaction environment
#
# Padash , jaza
# ag doros anjam dad, mohit behesh padash bde --> doros anjam dadi
# ag ghalat anjam dad --> mohit jaza bede --> doro nadadi
#
# hey done done k ba taamol dsar mohtie , kam kam yad migire--->
# reinforcement learning --> RL --> robotic estefade mishe , game , reasoning

# %%
# Mesal ----> yek dastgahi ---> 3d printing , ... dar har reshte ee
# Process parameetrs --> settinge oon dastgah --> shoam taeen mikoni , tanzimesh mikonim
#kareto anjam , chAp mikone, --> kareto besanji --> criteria 
# Quality aprameter -->  esthekam , shafafiat , (azmayesh bedast maid, ba cheshm ,....)


#Process parameter taghir midi --> quality parameter taghir mikone

#3d printing --> sorate chapo taghir bdm --> quality aprmasete rtaghir peyda mikone
#ama aya mitonm bgm ba ch sorati ? rabete hads bznm? kheyr nmishe


#----> ML (BOX )

#data --> 10 , 12 tra azmayesh anjam midadam --> 10 ,12 estehakm

#vroodi (proces aprmaetr / khoroji (estehkam) 

#hala rabete ro dar bair


#ML ---> model haye amari ---> mrie rabete ro dar miare 


#estehakm = 134*sdpeed + 2323

#speed ---> vorodimo bdm 
#esteham


#yed begire az data , bare asase data amal , tasmim bgir e--> pishbini bokone


'''

3D PRINTING

----> PROCES PARMAETER --> SPEED , TEMP ,......

---> speed | default 

#volume --> 0 ta 100 taghiresh bdi
#estehkam --> 1 ta 1000

speed --> 10  ---> estehkam --> 30
speed--->20 ---> esthkam ---> 230
speed---> 30 ---> esthkam --> 450 
speed--> 40 --> esthkam --> 570
speed--->50 --->esthkam --> 610

#speed ---- esthkam hast 
#va man donablesham


#donbake--> balatarin estehkam ro bdast bairma 
#speed --> 100 --> esthekam 1000? --> kheyr nmsihe gof --> man daram hads mzinm fght
#rabte he ro dar nayovrodm


yek rabete speed ? estehkam --> khdoa nemidonatesh
nature --> sorat --> y etasiri dare ba oon filamnet ha , dynamic sayal dar lahzeye zop , molecular dynamic , va ba solidifcation / 
estehkam . pichidan , modelsazi nmsihe, kh az parmaeter tasir gozar hasan

estehkam = a * speed + b


###estehakm = exponential (sin ( radical (speed * 11298237) + radical (speeed * 18 ) + ....

## hamsihe y process parameter ndri
#speed , temp , multiplier , 

#speed bala --> esthekam kam bshe
#temp bala --> esthekam ziad bshe
#speed , tmep baham bbri bala ?
#3 ta 5 ta 6 tya


speed , time , temp ---> bone --> balatarin estehkame momken ro mikhay

temp 0 - 100
time 0 - 100
speed 0 - 100 

temp 0
speed 10 
time 10
(print tool  mikeshe , hazine dari , mavadesh , khdoe dastgah)
azmayuesh koni  , azmayehs anjam 
3,4 saaat 
estehakm -- > 120



temp 10
speed 0
time 0 
estehkam-->130




100 * 100 * 100 ----> 10000000 1 million bar bayad anjam bdi

az gheyamt 
1000000 * 3,4 ---> 3 ,4 million saaat tool mikshe  --> 300 sal bekoob

450 sal ba khab tool mikshe


mnahayat mitoni bhri
30 ta azmayehs bgiri


ey kash yek modeli bood
mitones rabete ye beyne proces parmaeter -- quality parameter 
ey kash rabete ro mitones dar baire


estehakm = 89*speed + 36*temp + 10*time + 1000


barname 100000 halato midm b in --> 1000 esthkam tahvil migirm 2 daghighe ( darsade khataee)

miram balatarin estehakme momkenoi mibinm , ahan too in temp, speed, time --> bhtrin estehkam ro bgirm



esthkam 70 -80 



ML -->: betone in rabete ro bedast baire

'''
# Out:
# '\n\n3D PRINTING\n\n----> PROCES PARMAETER --> SPEED , TEMP ,......\n\n---> speed | default \n\n#volume --> 0 ta 100 taghiresh bdi\n#estehkam --> 1 ta 1000\n\nspeed --> 10  ---> estehkam --> 30\nspeed--->20 ---> esthkam ---> 230\nspeed---> 30 ---> esthkam --> 450 \nspeed--> 40 --> esthkam --> 570\nspeed--->50 --->esthkam --> 610\n\n#speed ---- esthkam hast \n#va man donablesham\n\n\n#donbake--> balatarin estehkam ro bdast bairma \n#speed --> 100 --> esthekam 1000? --> kheyr nmsihe gof --> man daram hads mzinm fght\n#rabte he ro dar nayovrodm\n\n\nyek rabete speed ? estehkam --> khdoa nemidonatesh\nnature --> sorat --> y etasiri dare ba oon filamnet ha , dynamic sayal dar lahzeye zop , molecular dynamic , va ba solidifcation / \nestehkam . pichidan , modelsazi nmsihe, kh az parmaeter tasir gozar hasan\n\nestehkam = a * speed + b\n\n\n###estehakm = exponential (sin ( radical (speed * 11298237) + radical (speeed * 18 ) + ....\n\n## hamsihe y process parameter ndri\n#speed , temp , multi
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

'''
excel , csv --> pandas
radif---> case --> data 
case --> sample

6 ta chap krdm 

---------data experiemental--------
id   speed    estehkam
1     10        120
2     20        250
3     30        320
4     40        480
5     50        510

5 tas data --> 5 ta radif --> 5 ta case rftm azmayesh krdm --. radif rows--> tedadse data
soton--> features --:> vizhegi ha --> vorodi , khoroji ha 

sotoon
vorodi ---> inputs (process parameters ) , variable haee k daste to hast , independent variable , --> features
khoorji --> output ( quality parameter , criteria) , target 



step 0.0---->data --> tamiz koni --> clean --> pandas

step 0.1.------> oon masaleye khodeto tabdil koni b yek masale input / output --> data


rabeteye beyne vorodi va khoroji
rbayteye beyne input output
rabetey beyne features and target


x
y





'''
data_array=np.array([ [10,120],[20,250],[30,370],[40,460],[50,510] ])

data=pd.DataFrame(data_array,columns=['speed','estehkam'])


#khjodam dasti zdm
#ama aksaran shoma data ro dari
#ama ba in pd.read_excel  / pd.read_csv --> data

#cleaning --> final_data --> datafgrame dariiiii

# %%
print(data)
# Out:
#    speed  estehkam
# 0     10       120
# 1     20       250
# 2     30       370
# 3     40       460
# 4     50       510

# %%
'''

dar donayye vaghei , nature , dar tabiat
yek rabete ee beyen speed va estehakm hast 


estehkam = 458 * speed + 230
khdoa midone , man nmidonm shoam nmidoni


mdoel

estehkam = a* speed + b
 a va b ro peyda kone 


estehkam = 400 * sdpeed + 200

speed --> estehkam 


pishbin mikone
baraye ma
 

'''
# Out:
# '\n\ndar donayye vaghei , nature , dar tabiat\nyek rabete ee beyen speed va estehakm hast \n\n\nestehkam = 458 * speed + 230\nkhdoa midone , man nmidonm shoam nmidoni\n\n\nmdoel\n\nestehkam = a* speed + b\n a va b ro peyda kone \n\n\nestehkam = 400 * sdpeed + 200\n\nspeed --> estehkam \n\n\npishbin mikone\nbaraye ma\n \n\n'

# %%
x=data['speed'] #input , proces parmaeter, feature
y=data['estehkam'] #output , qualitry parameter , target

plt.scatter(x,y)
plt.xlabel('speed')
plt.ylabel('estehkam')
plt.title('dade haye azmayeshgahi')
plt.grid()
plt.show()

# %%
#szhoma har khate safio 
#fght ba yek a va b mitoni bsazi

#y = 4x + 10

myx=np.arange(0,1000)
myy=5*myx + 100
myy2=6*myx+100
myy3=7*myx+6000

plt.scatter(myx,myy,c='r',label='shibe 5 , arz 100')
plt.scatter(myx,myy2,c='b',label='shibe 6 , arz 100')
plt.scatter(myx,myy3,c='g',label='shibe 7 , arz 6000')
plt.legend()
plt.show()

# %%
myx=np.arange(0,50)
myy=5*myx + 100
myy2=6*myx+100
myy3=7*myx+200
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 5 , arz 100')
plt.plot(myx,myy2,c='b',label='shibe 6 , arz 100')
plt.plot(myx,myy3,c='g',label='shibe 7 , arz 6000')
plt.legend()
plt.grid()
plt.show()

# %%
myx=np.arange(0,50)
myy=5*myx + 100
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 5 , arz 100')

plt.legend()
plt.grid()
plt.show()

# %%
myx=np.arange(0,50)
myy=7*myx + 100
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 7 , arz 100')

plt.legend()
plt.grid()
plt.show()

# %%
myx=np.arange(0,50)
myy=8*myx + 100
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 8 , arz 100')

plt.legend()
plt.grid()
plt.show()

# %%
myx=np.arange(0,50)
myy=9*myx + 100
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 9, arz 100')

plt.legend()
plt.grid()
plt.show()

# %%
myx=np.arange(0,50)
myy=9*myx + 30
plt.scatter(x,y,c='k',label='experimental data')
plt.plot(myx,myy,c='r',label='shibe 9, arz 30')

plt.legend()
plt.grid()
plt.show()

# %%
#y = 9 * x + 30

#data --> speed / estehkam

#estehkam = 9 * speed + 30


#100 --> 9*100 =900 + 30 = 930


myx=np.arange(0,100)
myy=9*myx + 30
plt.plot(myx,myy,c='r',label='shibe 9, arz 30')
plt.legend()
plt.grid()
plt.show()

# %%
#in kahte hamoon khate bodo k man donbalesh boodam va peydash krdm khodaroshok

# %%
#tabe(vorodi)

#class.tabe(voirodi)
'''


Hame ye kar -->psihbini


(1)-----
train , fit , anjam bdi ---> data bedi bere yad bgire

(2)----
predict --> pishbini


'''


'''
class Linearregressor:

    def __init__(self):
        pass

    def fit(self,x,y):
        #100 ta 1
        #100 ta b 

        cost_function=[]

        #100000 khat mitonm bsazam
        #shoam naiz dari algorithem haye yekam p;ichide tar --> optimziation 
        #hoshmandane bere
        #a mibare bala bbine dar ehey cost function --> baid paeen
        #gradiant decent --> gradian kaheshi
        for a in range(0,100):
            for b in range(0,100):
                #i=0 j=0
                #i=0 j=1
                #i=0 ....
                #i=0 j=100
                
                #i=1

                myline=a*x+ b
                
                #fdasleeye beyne y , myline 
                cost_function.append((myline-y)**2)


        min(cost_function) ---> a,b

        coef_ = a
        intercept_ = b
        #y=a+b
        print('done')



    def predict(self,x):
        mypredict = coef_  * x + intercept_
        return mypredict

'''
# Out:
# "\nclass Linearregressor:\n\n    def __init__(self):\n        pass\n\n    def fit(self,x,y):\n        #100 ta 1\n        #100 ta b \n\n        cost_function=[]\n\n        #100000 khat mitonm bsazam\n        #shoam naiz dari algorithem haye yekam p;ichide tar --> optimziation \n        #hoshmandane bere\n        #a mibare bala bbine dar ehey cost function --> baid paeen\n        #gradiant decent --> gradian kaheshi\n        for a in range(0,100):\n            for b in range(0,100):\n                #i=0 j=0\n                #i=0 j=1\n                #i=0 ....\n                #i=0 j=100\n                \n                #i=1\n\n                myline=a*x+ b\n                \n                #fdasleeye beyne y , myline \n                cost_function.append((myline-y)**2)\n\n\n        min(cost_function) ---> a,b\n\n        coef_ = a\n        intercept_ = b\n        #y=a+b\n        print('done')\n\n\n\n    def predict(self,x):\n        mypredict = coef_  * x + intercept_\n        retu
# ...

# %%
'''
sklearn
Scikit learn --> sklearn --> ketabkhone ---> Machine learning

https://scikit-learn.org/stable/

pip install scikit-learn

https://pypi.org/project/scikit-learn/

https://github.com/scikit-learn/scikit-learn


Model haye mokhtalefe hoosh emasnoe dare
supervid learnign --> 6 ta mdoele
unsupervised learning --> 3,4 mdoel emaroof




Supervised learning -- > Linearregression --> too dele khdoesah darer



inpit ---> output ro b ye raveshi mire dar maire
sade tarin ravehs bood 

Linearregression
K nearest enighbour
decision tree
random forest
support vector machine
multy layer perceptron (artificial neural network)



Linearregressor

#step0.0------ data clean

#step0.1 --> x , y 


#----step1 ---> sklearn
#model ro bsaz
model = class()


model.fit(x,y)
#fght peyda  mikone , cost function 
#algorithemi k mire khat ro peyda mikone 


#y= a*x + b
model.predict(x) ---> y




'''
# Out:
# '\nsklearn\nScikit learn --> sklearn --> ketabkhone ---> Machine learning\n\nhttps://scikit-learn.org/stable/\n\npip install scikit-learn\n\nhttps://pypi.org/project/scikit-learn/\n\nhttps://github.com/scikit-learn/scikit-learn\n\n\nModel haye mokhtalefe hoosh emasnoe dare\nsupervid learnign --> 6 ta mdoele\nunsupervised learning --> 3,4 mdoel emaroof\n\n\n\n\nSupervised learning -- > Linearregression --> too dele khdoesah darer\n\n\n\ninpit ---> output ro b ye raveshi mire dar maire\nsade tarin ravehs bood \n\nLinearregression\nK nearest enighbour\ndecision tree\nrandom forest\nsupport vector machine\nmulty layer perceptron (artificial neural network)\n\n\n\nLinearregressor\n\n#step0.0------ data clean\n\n#step0.1 --> x , y \n\n\n#----step1 ---> sklearn\n#model ro bsaz\nmodel = class()\n\n\nmodel.fit(x,y)\n#fght peyda  mikone , cost function \n#algorithemi k mire khat ro peyda mikone \n\n\n#y= a*x + b\nmodel.predict(x) ---> y\n\n\n\n\n'

# %%
'''
import sklearn as ..... injoroi nis

from sklearn import ....

sklearn 
linarmodels
mdoel selction
tree models
ensemble mdoels



from sklearn.section import ....





'''



from sklearn.linear_model import LinearRegression



#-----step0--------
data_array=np.array([ [10,120],[20,250],[30,370],[40,460],[50,510] ])
data=pd.DataFrame(data_array,columns=['speed','estehkam'])

x=np.array(data['speed'])
y=np.array(data['estehkam'])



#----step1-------
model=LinearRegression()

# %%
#trainign, fit 
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
#A , B
a=model.coef_

b=model.intercept_

print('shibe man : ',a)
print('artz az mabdae man : ',b)
#myy=9*myx + 30
# Out:
# shibe man :  [9.9]
# artz az mabdae man :  45.00000000000006

# %%
x_pred=np.arange(0,100)

y_pred=a[0]*x_pred+b



plt.scatter(x_pred,y_pred,label='predicted')
plt.scatter(x.reshape(1,-1),y,label='experimental')
plt.legend()
plt.show()
